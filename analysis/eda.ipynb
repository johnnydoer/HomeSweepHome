# %% [markdown]
# ### This in Exploratory Data Analysis in Polars library.

# %%
import polars as pl
import pandas as pd

# %%
# %%time
df_csv1 = pl.read_csv("get_delhi.csv")
# Out:
# CPU times: user 26.2 ms, sys: 28.9 ms, total: 55 ms
# Wall time: 53.3 ms

# %%
# %%time
df_csv2 = pd.read_csv("get_delhi.csv")
# Out:
# CPU times: user 122 ms, sys: 47 ms, total: 169 ms
# Wall time: 202 ms

# %%
df_csv.describe()
# Out:
# shape: (7, 19)
# ┌──────────┬──────────┬──────────┬────────────┬─────┬────────┬────────────┬────────────┬───────────┐
# │ describe ┆ title    ┆ subtitle ┆ is_active_ ┆ ... ┆ price  ┆ built_up_a ┆ built_up_a ┆ emi       │
# │ ---      ┆ ---      ┆ ---      ┆ property   ┆     ┆ ---    ┆ rea_value  ┆ rea_unit   ┆ ---       │
# │ str      ┆ str      ┆ str      ┆ ---        ┆     ┆ str    ┆ ---        ┆ ---        ┆ str       │
# │          ┆          ┆          ┆ f64        ┆     ┆        ┆ f64        ┆ str        ┆           │
# ╞══════════╪══════════╪══════════╪════════════╪═════╪════════╪════════════╪════════════╪═══════════╡
# │ count    ┆ 21301    ┆ 21301    ┆ 21301.0    ┆ ... ┆ 21301  ┆ 21301.0    ┆ 21301      ┆ 21301     │
# │ null_cou ┆ 0        ┆ 0        ┆ 0.0        ┆ ... ┆ 0      ┆ 0.0        ┆ 0          ┆ 0         │
# │ nt       ┆          ┆          ┆            ┆     ┆        ┆            ┆            ┆           │
# ...

# %%
df_csv.select(
    pl.col("foo")
)
